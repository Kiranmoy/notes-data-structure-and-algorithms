# %% [markdown]
# # What is a Binary Search Tree?

# %% [markdown]
# A Binary Search Tree is a Binary Tree with following conditions:
# - In the left subtree the value of a node is less than or equal to its parent node’s value.
# - In the right subtree the value of a node is greater than its parent node’s value.
#
# ![image.png](attachment:4cec1f1f-7167-46cd-a8f5-c0bcb207458c.png)

# %% [markdown]
# # Why Binary Search Tree?

# %% [markdown]
# **It performs faster than Binary Tree when inserting and deleting nodes.**
# * Instead of traversing every element sequentially until the right one is found.
# * Here we need to traverse only the half tree, then next half child-tree, and so on.
#
# ![image.png](attachment:2abbb0ae-25e6-4e9b-9d39-8e0e8eea2326.png)

# %% [markdown]
# # Common Operations on Binary Search Tree

# %% [markdown]
# - Creation of Tree
# - Insertion of a node
# - Deletion of a node
# - Search for a value
# - Traverse all nodes
# - Deletion of tree
