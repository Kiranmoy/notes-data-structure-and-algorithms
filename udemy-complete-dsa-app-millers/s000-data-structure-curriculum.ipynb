# %% [markdown]
# **Introduction to DSA**
# * What are Data structure and algorithm?
# * Why do we need them?
#
# **Recursion**
#
# **Cracking Recursion questions**
#
# **Big O notation - performance & efficiency of code**
#
# **Cracking Big O interview questions**
#
# **Arrays**
# * One dimensional arrays
# * Two-dimensional arrays
# * Memory representation
# * Time & space complexity of array operations
#
# **Python list**
#
# **Difference between arrays & lists**
#
# **Cracking Array/List interview questions**
#
# **Dictionary**
#
# **Tuples**
#
# **Linked List**
# * Single linked list & operations
# * Circular single linked list & operations
# * Doubly Linked list & operations
# * Circular Doubly linked list
#
# **Cracking Linked list interview questions**
#
# **Stacks**
#
# **Queues**
#
# **Cracking stack/queue interview questions**
#
# **Tree/Binary tree**
# * Pre-order traversal
# * In-order traversal
# * Post-order traversal
# * level order traversal
#
# **Binary search tree**
#
# **AVL tree**
# * Left-Left conditions
# * Left-Right conditions
# * Right-Left conditions
#
# **Binary Heap & common operations**
#
# **Trie**
#
# **Hashing**
# * How does Python’s built-in data structure work?
# * How they are implemented behind the scenes?
#
# **Sorting algorithms**
# * Bubble sort
# * Selection sort
# * Insertion sort
# * Bucket sort
# * Merge sort
# * Quick sort
# * Heap sort
#
# **Graph algorithm**
# * Breadth-First Search
# * Depth First Search
# * Topological sort
# * Single source path problems
# * All pairs shortest-path problems
#     * Dijktra’s algorithm
#     * Bellman ford algorithm
#     * Floyd warshall algorithm
# * Minimum Spanning Tree
#     * Prim’s algorithm
#     * Kruskal algorithm
#
# **Greedy Algorithms**
# * Activity Selection Problem
# * Coin Change Problem
# * Fractional Knapsack problem
#
# **Divide & Conquer Algorithms**
# * Number Factor Problem
# * House Robber Problem
# * Convert one string to another string
# * Zero-one Knapsack problem
# * Longest Common Sub-Sequence problem
# * Longest Palindromic sub-sequence/string
# * Minimum cost path problem
#
# **Dynamic Programming**
# * Main properties
# * optimal sub-structure properties
# * overlapping sub-problems
# * Two methods
#     * Top-Down Memorization
#     * Bottom-Up Tabulation
# * Common DC problems
#     * Number Factor
#     * House Robber problen
#     * Convert one string to another
#     * Zero one knapsack problem using DC
#
# **Challenging Dynamic programming exercises**
#
# **The wild west  - coding exercises including all concepts**
