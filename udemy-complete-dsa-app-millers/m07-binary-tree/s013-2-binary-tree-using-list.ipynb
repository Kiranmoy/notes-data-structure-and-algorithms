# %% [markdown]
# # Binary Tree implementation using Python List

# %%
class BinaryTree:
    def __init__(self, size):
        self.customList = size * [None]
        self.lastUsedIndex = 0
        self.maxSize = size
    
    def insertNode(self, value):
        if self.lastUsedIndex + 1 == self.maxSize:
            return "The Binary Tree is full"
        self.customList[self.lastUsedIndex+1] = value
        self.lastUsedIndex += 1
        return "The value has been successfully inserted"

    def searchNode(self, nodeValue):
        for i in range(len(self.customList)):
            if self.customList[i] == nodeValue:
                return "Success"
        return "Not found"
    
    def preOrderTraversal(self, index):
        if index > self.lastUsedIndex:
            return
        print(self.customList[index])
        self.preOrderTraversal(index*2)
        self.preOrderTraversal(index*2 + 1)

    def inOrderTraversal(self, index):
        if index > self.lastUsedIndex:
            return
        self.inOrderTraversal(index*2)
        print(self.customList[index])
        self.inOrderTraversal(index*2+1)
    
    def postOrderTraversal(self, index):
        if index > self.lastUsedIndex:
            return
        self.postOrderTraversal(index*2)
        self.postOrderTraversal(index*2+1)
        print(self.customList[index])
    
    def levelOrderTraversal(self, index):
        for i in range(index, self.lastUsedIndex+1):
            print(self.customList[i])
    
    def deleteNode(self, value):
        if self.lastUsedIndex == 0:
            return "There is not any node to delete"
        for i in range(1, self.lastUsedIndex+1):
            if self.customList[i] == value:
                self.customList[i] = self.customList[self.lastUsedIndex]
                self.customList[self.lastUsedIndex] = None
                self.lastUsedIndex -= 1
                return "The node has been successfully deleted"
    
    def deleteBT(self):
       self.customList = None
       return "The BT has been successfully deleted"

    
newBT = BinaryTree(8)
newBT.insertNode("Drinks")
newBT.insertNode("Hot")
newBT.insertNode("Cold")
newBT.insertNode("Tea")
newBT.insertNode("Coffee")

newBT.levelOrderTraversal(1)
print()
print(newBT.deleteBT())
# Out:
# Drinks
# Hot
# Cold
# Tea
# Coffee
#
# The BT has been successfully deleted

# %% [markdown]
# # Create Binary Tree using Python List

# %% [markdown]
# ![image.png](attachment:90238df6-a9d2-4244-9032-c21db1d1d293.png)
#
# ![image.png](attachment:b8f6691c-752d-4d6f-bda4-5a2220e07c36.png)
#
# ![image.png](attachment:600d2649-3fab-433b-87e1-3e323395e020.png)
#
# ![image.png](attachment:1abb6e50-e4e3-4c74-af9c-8dc4aec261e8.png)
#
# ![image.png](attachment:e695aecb-88dd-4200-a0e9-f73d8e858c4f.png)
#
# ```
# newBT = BTclass()
# Fixed size Python List
# lastUsedIndex
# ```
#
# ![image.png](attachment:4fd29b4a-7f0a-4622-987c-05fff1d03cda.png)
#
# **Implmentation**
#
# ```python
# class BinaryTree:
#     def __init__(self, size): # size includes total number of elements + 1
#         self.customList = size * [None]
#         self.lastUsedIndex = 0
#         self.maxSize = size
# ```

# %% [markdown]
# # Insert a node in Binary Tree

# %% [markdown]
# ![image.png](attachment:9c56f164-8541-4d37-a33b-35471e6f6922.png)
#
# **Implementation**
#
# ```python
# def insertNode(self, value):
#     if self.lastUsedIndex + 1 == self.maxSize:
#         return "The Binary Tree is full"
#     self.customList[self.lastUsedIndex+1] = value
#     self.lastUsedIndex += 1
#     return "The value has been successfully inserted"
# ```

# %% [markdown]
# # Searching for a node in Binary Tree (python list)

# %% [markdown]
# ![image.png](attachment:6e43d43a-ac45-48ba-b6b7-62529d90ce81.png)
#
# **Implementation**
#
# ```python
# def searchNode(self, nodeValue):
#     for i in range(len(self.customList)):
#         if self.customList[i] == nodeValue:
#             return "Success"
#     return "Not found"
# ```

# %% [markdown]
# # PreOrder Traversal of Binary Tree

# %% [markdown]
# ![image.png](attachment:e4c75740-5334-4c45-a475-a5c88f1d4416.png)
#
# ![image.png](attachment:1cfc0e87-5181-4ad8-a762-886984f45b25.png)
#
# **Implementation**:
#
# ```python
#     def preOrderTraversal(self, index):
#         if index > self.lastUsedIndex:
#             return
#         print(self.customList[index])
#         self.preOrderTraversal(index*2)
#         self.preOrderTraversal(index*2 + 1)
#
# ```

# %% [markdown]
# # InOrder Traversal of Binary Tree

# %% [markdown]
# ![image.png](attachment:c7c29bb9-865b-4ea0-8e85-fdd9c7021665.png)
#
# ![image.png](attachment:8063f0ce-6ded-4143-bdb9-62a041b1d965.png)
#
# **Implementation**:
#
# ```python
#     def inOrderTraversal(self, index):
#         if index > self.lastUsedIndex:
#             return
#         self.inOrderTraversal(index*2)
#         print(self.customList[index])
#         self.inOrderTraversal(index*2+1)
#
# ```

# %% [markdown]
# # PostOrder Traversal of Binary Tree

# %% [markdown]
# ![image.png](attachment:c0786ea0-ec72-4dfc-aa79-f436640fd772.png)
#
# ![image.png](attachment:6e0fb5eb-cc24-4e42-a156-fe8307578b24.png)
#
# **Implementation**:
#
# ```python
#     def postOrderTraversal(self, index):
#         if index > self.lastUsedIndex:
#             return
#         self.postOrderTraversal(index*2)
#         self.postOrderTraversal(index*2+1)
#         print(self.customList[index])
#
# ```

# %% [markdown]
# # LevelOrder Traversal of Binary Tree

# %% [markdown]
# ![image.png](attachment:3982d603-369e-4dea-ab4d-acb5e1e21aa2.png)
#
# ![image.png](attachment:ce5a0e36-fb4f-41f8-a920-0c74b9937e4a.png)
#
# **Implementation**:
#
# ```python
#     def levelOrderTraversal(self, index):
#         for i in range(index, self.lastUsedIndex+1):
#             print(self.customList[i])
# ```

# %% [markdown]
# # Delete a node from Binary Tree

# %% [markdown]
# ![image.png](attachment:ad690df2-cb00-4dac-b5e9-59dc9b8f3848.png)
#
# ![image.png](attachment:be0148ab-4f49-4ecb-bef4-d2b3286e8c66.png)
#
# **Implementation**:
#
# ```python
#     def deleteNode(self, value):
#         if self.lastUsedIndex == 0:
#             return "There is not any node to delete"
#         for i in range(1, self.lastUsedIndex+1):
#             if self.customList[i] == value:
#                 self.customList[i] = self.customList[self.lastUsedIndex]
#                 self.customList[self.lastUsedIndex] = None
#                 self.lastUsedIndex -= 1
#                 return "The node has been successfully deleted"
# ```

# %% [markdown]
# # Delete entire Binary Tree

# %% [markdown]
# ![image.png](attachment:24e0a6f1-40f1-4a93-9d27-5a0155e65402.png)
#
# **Implementation**:
#
# ```python
#     def deleteBT(self):
#        self.customList = None
#        return "The BT has been successfully deleted"
# ```
